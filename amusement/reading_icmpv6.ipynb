# %%
from scapy.all import *

#affichage de toutes les trames
trames=rdpcap("icmpv6.pcapng")
trames.show()
# Out:
# 0000 Ether / IPv6 / ICMPv6ND_RA / ICMPv6NDOptPrefixInfo / ICMPv6NDOptRDNSS / ICMPv6NDOptMTU / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address b0:cc:fe:82:28:94
# 0001 Ether / fe80::1b18:31d6:199c:e1fd > ff02::16 (0) / IPv6ExtHdrHopByHop / ICMPv6MLReport2
# 0002 Ether / fe80::1b18:31d6:199c:e1fd > ff02::16 (0) / IPv6ExtHdrHopByHop / ICMPv6MLReport2
# 0003 Ether / IPv6 / ICMPv6ND_NS / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address b0:cc:fe:82:28:94
# 0004 Ether / IPv6 / ICMPv6ND_NS / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address b0:cc:fe:82:28:94
# 0005 Ether / IPv6 / ICMPv6ND_NS / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address b0:cc:fe:82:28:94
# 0006 Ether / IPv6 / ICMPv6ND_NA / ICMPv6 Neighbor Discovery Option - Destination Link-Layer Address e8:84:a5:c8:4b:9b
# 0007 Ether / IPv6 / ICMPv6ND_NS / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address b0:cc:fe:82:28:94
# 0008 Ether / IPv6 / ICMPv6ND_NS / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address e8:84:a5:c8:4b:9b
# 0009 Ether / IPv6 / ICMPv6 Neighbor Discovery - Neighbor Advertisement (tgt: fe80::b2cc:feff:fe82:2894)
# 0010 Ether / IPv6 / ICMPv6ND_NS / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address e8:84:a5:c8:4b:9b
# 0011 Ether / IPv6 / ICMPv6ND_NA / ICMPv6 Neighbor Discovery Option - Destination Link-Layer Address b0:cc:fe:82:28:94
# 0012 Ether / IPv6 / ICMPv6 Echo Request (id: 0x11 seq: 0x1)
# 0013 Ether / IPv6 / ICMPv6 Echo Reply (id: 0x11 seq: 0x1)
# 0014 Ether / IPv6 / ICMPv6 Echo Request (id: 0x11 seq: 0x2)
# 0015 Ether / IPv6 / ICMPv6 Echo Reply (id: 0x11 seq: 0x2)
# 0016 Ether / IPv6 / ICMPv6 Echo Request (id: 0x11 seq: 0x3)
# 0017 Ether / IPv6 / ICMPv6 Echo Reply (id: 0x11 seq: 0x3)
# 0018 Ether / IPv6 / ICMPv6 Echo Request (id: 0x11 seq: 0x4)
# 0019 Ether / IPv6 / ICMPv6 Echo Reply (id: 0x11 seq: 0x4)
# 0020 Ether / IPv6 / ICMPv6 Echo Request (id: 0x11 seq: 0x5)
# 0021 Ether / IPv6 / ICMPv6 Echo Reply (id: 0x11 seq: 0x5)
# 0022 Ether / IPv6 / ICMPv6 Echo Request (id: 0x11 seq: 0x6)
# 0023 Ether / IPv6 / ICMPv6 Echo Reply (id: 0x11 seq: 0x6)
# 0024 Ether / IPv6 / ICMPv6ND_NS / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address b0:cc:fe:82:28:94
# 0025 Ether / IPv6 / ICMPv6 Neighbor Discovery - Neighbor Advertisement (tgt: fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091)
# 0026 Ether / IPv6 / ICMPv6 Echo Request (id: 0x11 seq: 0x7)
# 0027 Ether / IPv6 / ICMPv6 Echo Reply (id: 0x11 seq: 0x7)
# 0028 Ether / IPv6 / ICMPv6 Echo Request (id: 0x11 seq: 0x8)
# 0029 Ether / IPv6 / ICMPv6 Echo Reply (id: 0x11 seq: 0x8)
# 0030 Ether / IPv6 / ICMPv6 Echo Request (id: 0x11 seq: 0x9)
# 0031 Ether / IPv6 / ICMPv6 Echo Reply (id: 0x11 seq: 0x9)
# 0032 Ether / IPv6 / ICMPv6 Echo Request (id: 0x11 seq: 0xa)
# 0033 Ether / IPv6 / ICMPv6 Echo Reply (id: 0x11 seq: 0xa)
# 0034 Ether / IPv6 / ICMPv6ND_NS / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address e8:84:a5:c8:4b:9b
# 0035 Ether / IPv6 / ICMPv6 Neighbor Discovery - Neighbor Advertisement (tgt: fe80::b2cc:feff:fe82:2894)
# 0036 Ether / IPv6 / ICMPv6ND_NS / ICMPv6 Neighbor Discovery Option - Source Link-Layer Address b0:cc:fe:82:28:94
# 0037 Ether / IPv6 / ICMPv6 Neighbor Discovery - Neighbor Advertisement (tgt: fe80::1b18:31d6:199c:e1fd)

# %%
trames[15][IPv6][1].type
# trames[0][IPv6].show()
# Out:
# 129

# %%
dic={128: "echo-request", 129: "echo-reply"}

numéro_de_trame=0
for trame in trames:
    try:
        #la trame contient du arp
        trames[13][IPv6][1].type
        print(f"====================")
        print(f"La trame {numéro_de_trame} contient du ICMPv6")
        print(f"L'@MAC source est {trame[Ether].src}")
        print(f"L'@MAC destination est {trame[Ether].dst}")
        print(f"L'@IP source est {trame[IPv6].src}")
        print(f"L'@IP destination est {trame[IPv6].dst}")
        if trame[IPv6][1].type==128:
            print(f"echo-request")
        elif trame[IPv6][1].type==129:
            print(f"echo-reply")
        numéro_de_trame+=1
    except:
        numéro_de_trame+=1
        continue
# Out:
# ====================
# La trame 0 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fe80::b2cc:feff:fe82:2894
# L'@IP destination est ff02::1
# ====================
# La trame 1 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est 33:33:00:00:00:16
# L'@IP source est fe80::1b18:31d6:199c:e1fd
# L'@IP destination est ff02::16
# ====================
# La trame 2 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est 33:33:00:00:00:16
# L'@IP source est fe80::1b18:31d6:199c:e1fd
# L'@IP destination est ff02::16
# ====================
# La trame 3 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fe80::b2cc:feff:fe82:2894
# L'@IP destination est ff02::1:ff04:cb29
# ====================
# La trame 4 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fe80::b2cc:feff:fe82:2894
# L'@IP destination est ff02::1:ff77:95e2
# ====================
# La trame 5 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fe80::b2cc:feff:fe82:2894
# L'@IP destination est ff02::1:ff9c:e1fd
# ====================
# La trame 6 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est b0:cc:fe:82:28:94
# L'@IP source est fe80::1b18:31d6:199c:e1fd
# L'@IP destination est fe80::b2cc:feff:fe82:2894
# ====================
# La trame 7 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fe80::b2cc:feff:fe82:2894
# L'@IP destination est ff02::1:ff04:cb29
# ====================
# La trame 8 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est b0:cc:fe:82:28:94
# L'@IP source est fe80::1b18:31d6:199c:e1fd
# L'@IP destination est fe80::b2cc:feff:fe82:2894
# ====================
# La trame 9 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fe80::b2cc:feff:fe82:2894
# L'@IP destination est fe80::1b18:31d6:199c:e1fd
# ====================
# La trame 10 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est 33:33:ff:00:00:00
# L'@IP source est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# L'@IP destination est ff02::1:ff00:0
# ====================
# La trame 11 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fdb0:ccfe:8228:9400:b2cc:feff:fe82:2894
# L'@IP destination est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# ====================
# La trame 12 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est b0:cc:fe:82:28:94
# L'@IP source est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# L'@IP destination est fdb0:ccfe:8228:9400::
# echo-request
# ====================
# La trame 13 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fdb0:ccfe:8228:9400:b2cc:feff:fe82:2894
# L'@IP destination est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# echo-reply
# ====================
# La trame 14 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est b0:cc:fe:82:28:94
# L'@IP source est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# L'@IP destination est fdb0:ccfe:8228:9400::
# echo-request
# ====================
# La trame 15 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fdb0:ccfe:8228:9400:b2cc:feff:fe82:2894
# L'@IP destination est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# echo-reply
# ====================
# La trame 16 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est b0:cc:fe:82:28:94
# L'@IP source est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# L'@IP destination est fdb0:ccfe:8228:9400::
# echo-request
# ====================
# La trame 17 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fdb0:ccfe:8228:9400:b2cc:feff:fe82:2894
# L'@IP destination est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# echo-reply
# ====================
# La trame 18 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est b0:cc:fe:82:28:94
# L'@IP source est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# L'@IP destination est fdb0:ccfe:8228:9400::
# echo-request
# ====================
# La trame 19 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fdb0:ccfe:8228:9400:b2cc:feff:fe82:2894
# L'@IP destination est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# echo-reply
# ====================
# La trame 20 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est b0:cc:fe:82:28:94
# L'@IP source est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# L'@IP destination est fdb0:ccfe:8228:9400::
# echo-request
# ====================
# La trame 21 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fdb0:ccfe:8228:9400:b2cc:feff:fe82:2894
# L'@IP destination est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# echo-reply
# ====================
# La trame 22 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est b0:cc:fe:82:28:94
# L'@IP source est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# L'@IP destination est fdb0:ccfe:8228:9400::
# echo-request
# ====================
# La trame 23 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fdb0:ccfe:8228:9400:b2cc:feff:fe82:2894
# L'@IP destination est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# echo-reply
# ====================
# La trame 24 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fe80::b2cc:feff:fe82:2894
# L'@IP destination est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# ====================
# La trame 25 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est b0:cc:fe:82:28:94
# L'@IP source est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# L'@IP destination est fe80::b2cc:feff:fe82:2894
# ====================
# La trame 26 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est b0:cc:fe:82:28:94
# L'@IP source est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# L'@IP destination est fdb0:ccfe:8228:9400::
# echo-request
# ====================
# La trame 27 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fdb0:ccfe:8228:9400:b2cc:feff:fe82:2894
# L'@IP destination est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# echo-reply
# ====================
# La trame 28 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est b0:cc:fe:82:28:94
# L'@IP source est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# L'@IP destination est fdb0:ccfe:8228:9400::
# echo-request
# ====================
# La trame 29 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fdb0:ccfe:8228:9400:b2cc:feff:fe82:2894
# L'@IP destination est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# echo-reply
# ====================
# La trame 30 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est b0:cc:fe:82:28:94
# L'@IP source est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# L'@IP destination est fdb0:ccfe:8228:9400::
# echo-request
# ====================
# La trame 31 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fdb0:ccfe:8228:9400:b2cc:feff:fe82:2894
# L'@IP destination est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# echo-reply
# ====================
# La trame 32 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est b0:cc:fe:82:28:94
# L'@IP source est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# L'@IP destination est fdb0:ccfe:8228:9400::
# echo-request
# ====================
# La trame 33 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fdb0:ccfe:8228:9400:b2cc:feff:fe82:2894
# L'@IP destination est fdb0:ccfe:8228:9400:ace6:e88e:93d4:a091
# echo-reply
# ====================
# La trame 34 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est b0:cc:fe:82:28:94
# L'@IP source est fe80::1b18:31d6:199c:e1fd
# L'@IP destination est fe80::b2cc:feff:fe82:2894
# ====================
# La trame 35 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fe80::b2cc:feff:fe82:2894
# L'@IP destination est fe80::1b18:31d6:199c:e1fd
# ====================
# La trame 36 contient du ICMPv6
# L'@MAC source est b0:cc:fe:82:28:94
# L'@MAC destination est e8:84:a5:c8:4b:9b
# L'@IP source est fe80::b2cc:feff:fe82:2894
# L'@IP destination est fe80::1b18:31d6:199c:e1fd
# ====================
# La trame 37 contient du ICMPv6
# L'@MAC source est e8:84:a5:c8:4b:9b
# L'@MAC destination est b0:cc:fe:82:28:94
# L'@IP source est fe80::1b18:31d6:199c:e1fd
# L'@IP destination est fe80::b2cc:feff:fe82:2894
